# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
from pandas.plotting import lag_plot

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Import Data

# %%
#Importing data and parsing the dates

daily_temp_data = pd.read_csv('daily-minimum-temperatures.csv',parse_dates=True,index_col = 'Date')
daily_temp_data
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# ## 3. Data Understanding and EDA with Vizualization Charts

# %%
daily_temp_data.shape
# Out:
# (3650, 1)

# %%
daily_temp_data.dtypes
# Out:
# Temp    float64
# dtype: object

# %%
daily_temp_data.isna().sum()
# Out:
# Temp    0
# dtype: int64

# %%
daily_temp_data.plot()
plt.ylabel('Temp')
plt.show()

# %%
#displot 

sns.distplot(daily_temp_2['Temp'],hist=False)
plt.title('Temperature Distribution')
plt.show()

# %%
plt.boxplot(x = 'Temp',data = daily_temp_2)
plt.show()

# %% [markdown]
# #### LAG Plot

# %%
lag_plot(series = daily_temp_2 , lag=1)
plt.title('Lag Plot with 1 lag')
plt.show()

# %% [markdown]
# #### ACF Plot

# %%
plt.figure(figsize = (40,10))
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(daily_temp_2,lags=90)
plt.ylabel('Correlation Value')
plt.xlabel('Lags')
plt.show()
